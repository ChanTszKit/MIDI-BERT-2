# %%
from miditoolkit.midi import parser as mid_parser  
from miditoolkit.midi import containers as ct
from numpy import array, linspace
from sklearn.neighbors import KernelDensity
from matplotlib.pyplot import plot
from scipy.signal import argrelextrema
from scipy.ndimage import gaussian_filter1d
import numpy as np
from miditoolkit.pianoroll import parser as pr_parser
from miditoolkit.pianoroll import utils
import matplotlib.pyplot as plt
import math

# %%
# helper functions
def read_midi(path,tpb=0):
    global DEFAULT_RESOLUTION
    mido_obj = mid_parser.MidiFile(path)
    tick_per_beat = mido_obj.ticks_per_beat
    if tpb==0:
        DEFAULT_RESOLUTION = tick_per_beat
    else:
        DEFAULT_RESOLUTION = tpb

    notes = [] 
    for instrument in mido_obj.instruments:
        for note in instrument.notes:
            #rescale tpb to 480
            note.start = int(note.start/tick_per_beat*DEFAULT_RESOLUTION)
            note.end=int(note.end/tick_per_beat*DEFAULT_RESOLUTION)
            notes.append(note)

    # sort by start time
    notes.sort(key=lambda note:note.start)
    return notes,DEFAULT_RESOLUTION

def write_midi(notes,path='out.mid',tick_per_beat=480):
    out = mid_parser.MidiFile()
    out.ticks_per_beat = tick_per_beat
    out.instruments = [ct.Instrument(program=0,is_drum=False,name='right hand'),ct.Instrument(program=0,is_drum=False,name='left hand')]
    
    for note in notes:
        assert(note.velocity)
        current_beat=note.start//tick_per_beat
        centers = centers_per_beat[current_beat]
        closest_center,abs_distance_to_centers = cluster_assignment(note, centers_per_beat, tick_per_beat,single_note=True)
        if(closest_center==0):
            out.instruments[1].notes.append(ct.Note(start=note.start,end=note.end,pitch=note.pitch,velocity=note.velocity))
        else:
            out.instruments[0].notes.append(ct.Note(start=note.start,end=note.end,pitch=note.pitch,velocity=note.velocity))
    out.dump(path)

# def find_note_idx_start_before(notes, tick_per_beat, beat):
#     # binary search
#     notes = sorted(notes,key=lambda x:x.start)
#     target = beat*tick_per_beat-1
#     left=0
#     right=len(notes)-1
#     middle=(left+right+1)//2
#     while left<right:
#         if notes[middle].start == target:
#             if notes[middle+1].start==target:
#                 left=middle+1
#             else:
#                 break
#         elif notes[middle].start<target:
#             left=middle
#         else:
#             right=middle-1
#         middle=(left+right+1)//2
#     return middle

def get_notes_of_beat(notes,beat,tick_per_beat):
    start_tick=beat*tick_per_beat+1
    end_tick=(beat+1)*tick_per_beat-1
    return list(filter(lambda n: n.start<=start_tick<=n.end or n.start<=end_tick<=n.end, notes))

def get_centers_per_beat(notes, tick_per_beat,kernel_size=5):
    # find centers
    centers_per_beat=[]
    range_per_beat=[]
    
    length = math.ceil(max(notes,key=lambda x:x.end).end/tick_per_beat)
    for beat in range(length):
        notes_within_window = get_notes_of_beat(notes,beat,tick_per_beat)
        pitches_within_window = np.array([note.pitch for note in notes_within_window])
        if len(pitches_within_window)==0:
            range_per_beat.append(range_per_beat[-1])
            continue
        upper_limit,lower_limit = max(pitches_within_window),min(pitches_within_window)
        range_per_beat.append([lower_limit,upper_limit])
    
    pitch_range = linspace(0,127)
    for beat in range(length):
        notes_within_window = get_notes_of_beat(notes,beat,tick_per_beat)
        pitches_within_window = np.array([note.pitch for note in notes_within_window])
        if len(pitches_within_window)==0:
            centers_per_beat.append(centers_per_beat[-1])
            continue
            
        # use KDE for clustering(intervaling)(determine the center line for left/right hand respectively)
        pitches_within_window = pitches_within_window.reshape(-1,1)
        kernel_size=6
        #interatve clustering
        while True:
            kde = KernelDensity(kernel='gaussian', bandwidth=kernel_size).fit(pitches_within_window)
            kde_val = kde.score_samples(pitch_range.reshape(-1,1))
            # visualization: distribution of notes inside the window
            # plot(pitch_range, kde_val)
            minima, maxima = argrelextrema(kde_val, np.less)[0], argrelextrema(kde_val, np.greater)[0]
            
            
            #termination check
            if len(minima)>=1 and len(maxima)>=2:
                # cluster selection
                cutoff=min(pitch_range[minima])
                cluster_1_candidate = pitch_range[ maxima[pitch_range[maxima]<cutoff] ]
                cluster_2_candidate = pitch_range[ maxima[pitch_range[maxima]>cutoff] ]
                assert(len(cluster_1_candidate)>=1)
                assert(len(cluster_2_candidate)>=1)
                clusters= sorted([round(max(cluster_1_candidate)), round(max(cluster_2_candidate))])
                centers_per_beat.append(clusters)
                break
                
            elif kernel_size<0.0000001:
                #probably only one hand is needed
                pitches_within_window.sort()
                if len(notes_within_window)>=3:
                    centers_per_beat.append([round(np.average(pitches_within_window[:len(pitches_within_window)//2])),
                                         round(np.average(pitches_within_window[len(pitches_within_window)//2:]))])
                else:
                    centers_per_beat.append([round(np.average(pitches_within_window)),
                                         round(np.average(pitches_within_window))])
                break
            
            else:
                kernel_size*=0.7
                continue
                    
    #smooth the line
    centers_per_beat = np.array(centers_per_beat)
    centers_per_beat[:,0]=gaussian_filter1d(centers_per_beat[:,0], kernel_size)
    centers_per_beat[:,1]=gaussian_filter1d(centers_per_beat[:,1], kernel_size)
    return np.array(centers_per_beat),np.array(range_per_beat)

def cluster_assignment(notes, centers_per_beat, tick_per_beat, single_note=False):
    def center_ordering(centers_per_beat):
        # make sure the cluster with lower octave stay at index 0 (left hand)
        for center in centers_per_beat:
            if center[0]>center[1]:
                return False
        else:
            return True
    def assignment(note):
        current_beat=note.start//tick_per_beat
        centers = centers_per_beat[current_beat]
        abs_distance_to_centers=abs(note.pitch - centers)
        closest_center=np.argmin(abs_distance_to_centers)
        return closest_center,abs_distance_to_centers
    
    
    assert(center_ordering(centers_per_beat))
    if single_note == True:
        #return idx of cluster (0:left, 1:right)
        return assignment(notes)
    
    else:
        classified=[[],[]]
        abs_distance_to_classified_centers=[[],[]]
        for note in notes:
            closest_center,abs_distance_to_centers = assignment(note)
            classified[closest_center].append(note)
            abs_distance_to_classified_centers[closest_center].append(abs_distance_to_centers)            
        return classified,abs_distance_to_classified_centers

# %%
# filter long duration notes
def trim_long_notes(notes, tick_per_beat):
    def trim(note):
        if note.end-note.start>threshold*tick_per_beat:
            note.end = note.start+threshold*tick_per_beat
        return note
    
    threshold=4
    return list(map(trim, notes))

# %%
def octave_transpose(transpose_notes, tick_per_beat,threshold=10,center_threshold=5,minmaxrange=None):
    # octave transpose
    # for simplicity, use semitone instead of octave
    max_semitone_distance=threshold

    centers_per_beat,range_per_beat = get_centers_per_beat(transpose_notes, tick_per_beat,center_threshold)
    #use user provided range_per_beat
    if minmaxrange is not None:
        assert(len(minmaxrange)==len(range_per_beat))
        range_per_beat=minmaxrange
        
    transpose_track=[]
    skip_track=[]
    count=0
    skip_count=0

    for note_idx,note in enumerate(transpose_notes):
        # cluster assignment
        current_beat=note.start//tick_per_beat
        centers = centers_per_beat[current_beat]
        closest_center,abs_distance_to_centers = cluster_assignment(note, centers_per_beat, tick_per_beat,single_note=True)

        if abs_distance_to_centers[closest_center]>max_semitone_distance:
            # transpose
            start_beat = math.floor(note.start/tick_per_beat)
            end_beat = math.ceil(note.end/tick_per_beat)
            
            if note.pitch>centers[closest_center]:
                # transpose downward 
                # skip right hand
                if closest_center==0: 
                    transpose_notes[note_idx].pitch-=12*( ((abs_distance_to_centers[closest_center]-max_semitone_distance)//12) +1)
                    if transpose_notes[note_idx].pitch<min(range_per_beat[start_beat:end_beat+1,0]):#the tranposed note can never go beyond the skyline
                        transpose_notes[note_idx].pitch+=12
                    else:
                        count+=1
                else:
                    skip_count+=1
            else:
                # transpose upward
                if closest_center==1:
                    transpose_notes[note_idx].pitch+=12*( ((abs_distance_to_centers[closest_center]-max_semitone_distance)//12) +1)
                    if transpose_notes[note_idx].pitch>max(range_per_beat[start_beat:end_beat+1,0]):#the tranposed note can never go beyond the skyline
                        transpose_notes[note_idx].pitch-=12  
                    else:
                        count+=1
                else:
                    skip_count+=1
    
    # visualization : center line of left/right hand
    print('Octave Transpose:','#notes',len(transpose_notes),'transposed',count,'notes',', skipped',skip_count)
    #plot(centers_per_beat)
    
    return transpose_notes,centers_per_beat,range_per_beat

# %%
range_per_beat[15]
# Out:
# array([31, 83])

# %%
list(filter(lambda n:n.start<=56320 and n.end>=57344,notes))
# Out:
# [Note(start=55296, end=57344, pitch=71, velocity=70),
#  Note(start=55296, end=57344, pitch=55, velocity=70),
#  Note(start=56320, end=57344, pitch=81, velocity=88),
#  Note(start=56320, end=57344, pitch=52, velocity=70),
#  Note(start=56320, end=57344, pitch=59, velocity=70),
#  Note(start=56320, end=57344, pitch=55, velocity=70),
#  Note(start=56320, end=57344, pitch=90, velocity=75),
#  Note(start=56320, end=57344, pitch=93, velocity=82)]

# %%
temp=list(filter(lambda n:n.start<=56320 and n.end>=57344,notes))

# %%
out = mid_parser.MidiFile()
out.ticks_per_beat = tick_per_beat
out.instruments = [ct.Instrument(program=0,is_drum=False,name='debug')]
for note in temp:
    out.instruments[0].notes.append(ct.Note(start=note.start,end=note.end,pitch=note.pitch,velocity=note.velocity))
out.dump('out.mid')

# %%
def doubling_simplification(notes,centers_per_beat, tick_per_beat):
    notes = np.array(notes)
    count=0
    track_tick=0
    track_idx=0
    collections=[]
    delete=[]
    threshold=2 #max notes
    while track_idx<len(notes):
        if notes[track_idx].start==track_tick:
            # gathering notes start at the same tick
            collections.append(notes[track_idx])
            track_idx+=1
        else:
            # action
            classified,abs_distance_to_classified_centers = cluster_assignment(collections,centers_per_beat, tick_per_beat)
            keep=[[None for _ in range(12)] for __ in range(2)]
            # doubling simplification on different hand separately
            for group in range(2):
                note_count=0
                delete_candidates=[]
                for note in classified[group]:
                    if keep[group][note.pitch%12] is None:
                        keep[group][note.pitch%12] = note
                    elif keep[group][note.pitch%12].pitch>=note.pitch:
                        delete_candidates.append(note)
                    else:
                        delete_candidates.append(keep[group][note.pitch%12])
                        keep[group][note.pitch%12]=note
                    note_count+=1
                if note_count>threshold:
                    #remove doubling
                    delete_count = note_count-threshold
                    delete_candidates.sort(key=lambda x:x.pitch)
                    delete_candidates = delete_candidates[0:delete_count]
                    for note in delete_candidates:
                        delete.append(note)
            # reset
            collections=[notes[track_idx]]
            track_tick=notes[track_idx].start
            track_idx+=1
            
    for note in delete:
        notes = np.delete(notes, np.where(notes == note)[0])
        count+=1
            
    print('Doubling Simplification:','removed doubling',count)
    return notes

# %%
def merge_discrete_note(notes):
    notes.sort(key=lambda note:note.start)   
    org_len=len(notes)
    #profile
    all_pitch={}
    for note in notes:
        pitch=note.pitch
        if pitch in all_pitch:
            all_pitch[pitch].append(note)
        else:
            all_pitch[pitch]=[note]
    #merge
    for k,v in all_pitch.items():
        v.sort(key=lambda note:note.start)   
        trace_idx=0
        while trace_idx<len(v)-1:
            if 0<=v[trace_idx+1].start-v[trace_idx].end<=merge_threshold:
                v[trace_idx].end=v[trace_idx+1].end
                v.pop(trace_idx+1)
            else:
                trace_idx+=1
    #output
    notes=[]
    for k,v in all_pitch.items():
        for note in v:
            notes.append(note)
    notes.sort(key=lambda note:note.start)      
    filtered_len=len(notes)
    print('Merge discrete:','merged ',org_len-filtered_len,' discrete notes')
    return notes

# %%
def drop_discrete_note(notes):
    org_len=len(notes)
    
    new_notes=[]
    for note in notes:
        if note.end-note.start > discrete_note_threshold:
            new_notes.append(note)
    notes=new_notes        
    print('Drop discrete:','dropped ',org_len-len(notes),' discrete notes')
    return notes

# %%
def visualize(notes,tick_per_beat,centers_per_beat=None,range_per_beat=None,length=-1):
    old_resol = tick_per_beat
    new_resol = 24
    factor_down = new_resol/ old_resol
    print(factor_down,new_resol,old_resol)
    
    notes=sorted(notes,key=lambda note:note.start)
    if old_resol>=new_resol:
        # dowmsample
        pianoroll = pr_parser.notes2pianoroll(
                            notes, 
                            binary_thres=1,
                            resample_factor=factor_down)
    else:
        # upsmaple
        pianoroll = pr_parser.pianoroll2notes(
                            pianoroll,
                            binary_thres=1,
                            resample_factor=1/factor_down)
        
    pianoroll = pianoroll.astype(bool)
    plt.figure(figsize = (20,20))
    legend=[]
    
    if length==-1:
        plt.imshow(pianoroll.T, origin='lower')                
        if centers_per_beat is not None:
            plt.plot(np.repeat(centers_per_beat[:, [1, 0]],new_resol , axis=0))
            legend=['Right hand','Left hand']
        if range_per_beat is not None:
            plt.plot(np.repeat(range_per_beat[:, [1, 0]],new_resol , axis=0))
            legend+=['upperlimit','lowerlimit']
    else:
        plt.imshow((pianoroll[:length]).T, origin='lower')
        if centers_per_beat is not None:
            plt.plot(np.repeat(centers_per_beat[:, 1],new_resol , axis=0)[:length],color="red")
            plt.plot(np.repeat(centers_per_beat[:, 0],new_resol , axis=0)[:length],color="white")
            legend=['Right hand','Left hand']
        if range_per_beat is not None:
            plt.plot(np.repeat(range_per_beat[:, [1, 0]],new_resol , axis=0)[:length])
            legend+=['upperlimit','lowerlimit']
    plt.legend(legend)

    plt.show()

# %%
# main
merge_threshold=1# #minimum separation between notes in same pitch
discrete_note_threshold=1 #minimum length of a note

notes,tick_per_beat = read_midi("piano.mid")
org_notes=len(notes)
print(f'before post-processing {org_notes} notes')
notes = trim_long_notes(notes, tick_per_beat)
notes,centers_per_beat,range_per_beat = octave_transpose(notes, tick_per_beat)
notes = merge_discrete_note(notes)
notes = drop_discrete_note(notes)
notes = doubling_simplification(notes,centers_per_beat, tick_per_beat)
cur_notes=len(notes)
print(f'after post-processing, total notes: {cur_notes}, removed {org_notes-cur_notes} notes in total')
visualize(notes,tick_per_beat,centers_per_beat=centers_per_beat,range_per_beat=None,length=3000)
write_midi(notes, "post_processed.mid", tick_per_beat)

while True:
    notes,tick_per_beat = read_midi("post_processed.mid")
    org_notes=len(notes)
    print(f'before post-processing {org_notes} notes')
    notes = trim_long_notes(notes, tick_per_beat)
    notes,centers_per_beat,range_per_beat = octave_transpose(notes, tick_per_beat,5,2,range_per_beat)
    notes = merge_discrete_note(notes)
    notes = drop_discrete_note(notes)
    notes = doubling_simplification(notes,centers_per_beat, tick_per_beat)
    cur_notes=len(notes)
    print(f'after post-processing, total notes: {cur_notes}, removed {org_notes-cur_notes} notes in total')
    visualize(notes,tick_per_beat,centers_per_beat=centers_per_beat,range_per_beat=None,length=3000)
    write_midi(notes, "post_processed.mid", tick_per_beat)
    
    #termination
    if org_notes-cur_notes==0:        
        break
# Out:
# before post-processing 549 notes
# Octave Transpose: #notes 549 transposed 57 notes , skipped 50
# Merge discrete: merged  85  discrete notes
# Drop discrete: dropped  0  discrete notes
# Doubling Simplification: removed doubling 112
# after post-processing, total notes: 352, removed 197 notes in total
# 0.0234375 24 1024
# before post-processing 352 notes
# Octave Transpose: #notes 352 transposed 24 notes , skipped 76
# Merge discrete: merged  1  discrete notes
# Drop discrete: dropped  0  discrete notes
# Doubling Simplification: removed doubling 5
# after post-processing, total notes: 346, removed 6 notes in total
# 0.0234375 24 1024
# before post-processing 346 notes
# Octave Transpose: #notes 346 transposed 4 notes , skipped 69
# Merge discrete: merged  0  discrete notes
# Drop discrete: dropped  0  discrete notes
# Doubling Simplification: removed doubling 0
# after post-processing, total notes: 346, removed 0 notes in total
# 0.0234375 24 1024

# %%
    for beat in range(10):
        notes_within_window = get_notes_of_beat(notes,beat,tick_per_beat)
        pitches_within_window = np.array([note.pitch for note in notes_within_window])
        upper_limit,lower_limit = max(pitches_within_window),min(pitches_within_window)
        range_per_beat.append([lower_limit,upper_limit])

# %%
octave_transpose(notes, tick_per_beat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-6ebcc0c89c16> in <module>
# ----> 1 octave_transpose(notes, tick_per_beat)
#
# <ipython-input-95-3dcac994de93> in octave_transpose(transpose_notes, tick_per_beat, threshold, center_threshold, skylinerange)
#       4     max_semitone_distance=threshold
#       5
# ----> 6     centers_per_beat,range_per_beat = get_centers_per_beat(transpose_notes, tick_per_beat,center_threshold)
#       7     #use user provided range_per_beat
#       8     if skylinerange is not None:
#
# <ipython-input-93-bd512ccd655b> in get_centers_per_beat(notes, tick_per_beat, kernel_size)
#      69     length = max(notes,key=lambda x:x.end)
#      70
# ---> 71     for beat in range(length):
#      72         notes_within_window = get_notes_of_beat(notes,beat,tick_per_beat)
#      73         pitches_within_window = np.array([note.pitch for note in notes_within_window])
#
# TypeError: 'Note' object cannot be interpreted as an integer

# %%
centers_per_beat=[]
range_per_beat=[]

ahead=1
after=1

start=ahead
end=(notes[-1].start//tick_per_beat - after) +1

trace_start_idx=0

for beat in range(end):
    notes_within_window = notes[trace_start_idx:find_note_idx_before(notes, tick_per_beat, beat+1)+1]
    print(notes_within_window)
    pitches_within_window = np.array([note.pitch for note in notes_within_window])
    upper_limit,lower_limit = max(pitches_within_window),min(pitches_within_window)
    range_per_beat.append([lower_limit,upper_limit])
    trace_start_idx+=find_note_idx_before(notes, tick_per_beat, beat+1)+1
range_per_beat
# Out:
# [Note(start=0, end=3072, pitch=48, velocity=88), Note(start=0, end=3072, pitch=57, velocity=88), Note(start=0, end=3072, pitch=48, velocity=88), Note(start=0, end=3072, pitch=76, velocity=96), Note(start=0, end=3072, pitch=69, velocity=88), Note(start=0, end=3072, pitch=76, velocity=95)]
# []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-af1e33082d0a> in <module>
#      14     print(notes_within_window)
#      15     pitches_within_window = np.array([note.pitch for note in notes_within_window])
# ---> 16     upper_limit,lower_limit = max(pitches_within_window),min(pitches_within_window)
#      17     range_per_beat.append([lower_limit,upper_limit])
#      18     trace_start_idx+=find_note_idx_before(notes, tick_per_beat, beat+1)+1
#
# ValueError: max() arg is an empty sequence

# %%
# Out:
# [Note(start=6144, end=9216, pitch=40, velocity=92),
#  Note(start=6144, end=9216, pitch=52, velocity=92),
#  Note(start=6144, end=9216, pitch=55, velocity=92),
#  Note(start=6144, end=9216, pitch=59, velocity=92),
#  Note(start=6144, end=9216, pitch=76, velocity=92),
#  Note(start=6144, end=9216, pitch=67, velocity=100),
#  Note(start=6144, end=9216, pitch=71, velocity=92),
#  Note(start=6144, end=9216, pitch=79, velocity=99)]

# %%
notes
# Out:
# [Note(start=0, end=3072, pitch=48, velocity=88),
#  Note(start=0, end=3072, pitch=57, velocity=88),
#  Note(start=0, end=3072, pitch=48, velocity=88),
#  Note(start=0, end=3072, pitch=76, velocity=96),
#  Note(start=0, end=3072, pitch=69, velocity=88),
#  Note(start=0, end=3072, pitch=76, velocity=95),
#  Note(start=3072, end=6144, pitch=45, velocity=91),
#  Note(start=3072, end=6144, pitch=57, velocity=91),
#  Note(start=3072, end=6144, pitch=48, velocity=91),
#  Note(start=3072, end=6144, pitch=66, velocity=98),
#  Note(start=3072, end=6144, pitch=72, velocity=91),
#  Note(start=3072, end=6144, pitch=78, velocity=98),
#  Note(start=6144, end=9216, pitch=40, velocity=92),
#  Note(start=6144, end=9216, pitch=52, velocity=92),
#  Note(start=6144, end=9216, pitch=55, velocity=92),
#  Note(start=6144, end=9216, pitch=59, velocity=92),
#  Note(start=6144, end=9216, pitch=76, velocity=92),
#  Note(start=6144, end=9216, pitch=67, velocity=100),
#  Note(start=6144, end=9216, pitch=71, velocity=92),
#  Note(start=6144, end=9216, pitch=79, velocity=99),
#  Note(start=9216, end=12288, pitch=36, velocity=95),
#  Note(start=9216, end=12288, pitch=48, velocity=95),
#  Note(start=9216, end=12288, pitch=57, velocity=94),
#  Note(start=9216, end=12288, pitch=48, velocity=95),
#  Note(start=9216, end=12288, pitch=76, velocity=95),
#  Note(start=9216, end=12288, pitch=69, velocity=102),
#  Note(start=9216, end=12288, pitch=76, velocity=95),
#  Note(start=9216, end=12288, pitch=81, velocity=103),
#  Note(start=12288, end=15360, pitch=30, velocity=98),
#  Note(start=12288, end=15360, pitch=42, velocity=98),
#  Note(start=12288, end=15360, pitch=42, velocity=98),
#  Note(start=12288, end=15360, pitch=70, velocity=98),
#  Note(start=12288, end=15360, pitch=61, velocity=98),
#  Note(start=12288, end=15360, pitch=64, velocity=98),
#  Note(start=12288, end=15360, pitch=70, velocity=105),
#  Note(start=12288, end=15360, pitch=73, velocity=98),
#  Note(start=12288, end=15360, pitch=82, velocity=106),
#  Note(start=12288, end=18432, pitch=40, velocity=98),
#  Note(start=12288, end=18432, pitch=76, velocity=98),
#  Note(start=15360, end=18432, pitch=31, velocity=100),
#  Note(start=15360, end=18432, pitch=31, velocity=100),
#  Note(start=15360, end=18432, pitch=55, velocity=100),
#  Note(start=15360, end=18432, pitch=59, velocity=100),
#  Note(start=15360, end=18432, pitch=64, velocity=98),
#  Note(start=15360, end=18432, pitch=71, velocity=107),
#  Note(start=15360, end=18432, pitch=83, velocity=108),
#  Note(start=18432, end=21504, pitch=29, velocity=95),
#  Note(start=18432, end=21504, pitch=41, velocity=98),
#  Note(start=18432, end=21504, pitch=59, velocity=95),
#  Note(start=18432, end=21504, pitch=51, velocity=98),
#  Note(start=18432, end=21504, pitch=53, velocity=95),
#  Note(start=18432, end=21504, pitch=57, velocity=98),
#  Note(start=18432, end=21504, pitch=59, velocity=107),
#  Note(start=18432, end=21504, pitch=63, velocity=95),
#  Note(start=18432, end=21504, pitch=69, velocity=95),
#  Note(start=18432, end=21504, pitch=71, velocity=103),
#  Note(start=21504, end=24576, pitch=28, velocity=80),
#  Note(start=21504, end=24576, pitch=40, velocity=88),
#  Note(start=21504, end=24576, pitch=52, velocity=88),
#  Note(start=21504, end=24576, pitch=56, velocity=88),
#  Note(start=21504, end=24576, pitch=59, velocity=88),
#  Note(start=21504, end=24576, pitch=68, velocity=80),
#  Note(start=21504, end=24576, pitch=71, velocity=80),
#  Note(start=21504, end=24576, pitch=76, velocity=86),
#  Note(start=21504, end=25600, pitch=64, velocity=96),
#  Note(start=24576, end=25600, pitch=52, velocity=88),
#  Note(start=24576, end=26624, pitch=40, velocity=88),
#  Note(start=25600, end=26624, pitch=36, velocity=88),
#  Note(start=25600, end=26624, pitch=60, velocity=88),
#  Note(start=25600, end=26624, pitch=52, velocity=88),
#  Note(start=25600, end=26624, pitch=57, velocity=88),
#  Note(start=25600, end=26624, pitch=60, velocity=88),
#  Note(start=25600, end=27648, pitch=64, velocity=96),
#  Note(start=27648, end=28672, pitch=66, velocity=88),
#  Note(start=27648, end=29696, pitch=40, velocity=88),
#  Note(start=27648, end=29696, pitch=52, velocity=88),
#  Note(start=28672, end=29696, pitch=33, velocity=88),
#  Note(start=28672, end=29696, pitch=33, velocity=88),
#  Note(start=28672, end=29696, pitch=54, velocity=88),
#  Note(start=28672, end=29696, pitch=57, velocity=88),
#  Note(start=28672, end=29696, pitch=60, velocity=88),
#  Note(start=28672, end=29696, pitch=64, velocity=88),
#  Note(start=28672, end=30720, pitch=66, velocity=96),
#  Note(start=30720, end=31744, pitch=40, velocity=88),
#  Note(start=30720, end=31744, pitch=52, velocity=88),
#  Note(start=30720, end=31744, pitch=67, velocity=88),
#  Note(start=31744, end=32768, pitch=40, velocity=88),
#  Note(start=31744, end=32768, pitch=43, velocity=88),
#  Note(start=31744, end=32768, pitch=52, velocity=88),
#  Note(start=31744, end=32768, pitch=55, velocity=88),
#  Note(start=31744, end=32768, pitch=59, velocity=88),
#  Note(start=31744, end=32768, pitch=64, velocity=88),
#  Note(start=31744, end=33792, pitch=67, velocity=96),
#  Note(start=33792, end=34816, pitch=52, velocity=88),
#  Note(start=33792, end=34816, pitch=69, velocity=88),
#  Note(start=33792, end=35840, pitch=40, velocity=88),
#  Note(start=34816, end=35840, pitch=36, velocity=88),
#  Note(start=34816, end=35840, pitch=48, velocity=88),
#  Note(start=34816, end=35840, pitch=52, velocity=88),
#  Note(start=34816, end=35840, pitch=57, velocity=88),
#  Note(start=34816, end=35840, pitch=60, velocity=88),
#  Note(start=34816, end=35840, pitch=64, velocity=88),
#  Note(start=34816, end=36864, pitch=69, velocity=96),
#  Note(start=36864, end=37888, pitch=52, velocity=88),
#  Note(start=36864, end=37888, pitch=70, velocity=88),
#  Note(start=36864, end=38912, pitch=40, velocity=88),
#  Note(start=37888, end=38912, pitch=30, velocity=88),
#  Note(start=37888, end=38912, pitch=42, velocity=88),
#  Note(start=37888, end=38912, pitch=49, velocity=88),
#  Note(start=37888, end=38912, pitch=52, velocity=88),
#  Note(start=37888, end=38912, pitch=58, velocity=88),
#  Note(start=37888, end=38912, pitch=61, velocity=88),
#  Note(start=37888, end=38912, pitch=64, velocity=88),
#  Note(start=37888, end=39936, pitch=70, velocity=96),
#  Note(start=39936, end=40960, pitch=52, velocity=88),
#  Note(start=39936, end=40960, pitch=71, velocity=88),
#  Note(start=39936, end=41984, pitch=40, velocity=88),
#  Note(start=40960, end=41984, pitch=31, velocity=88),
#  Note(start=40960, end=41984, pitch=43, velocity=88),
#  Note(start=40960, end=41984, pitch=52, velocity=88),
#  Note(start=40960, end=41984, pitch=59, velocity=88),
#  Note(start=40960, end=41984, pitch=64, velocity=88),
#  Note(start=40960, end=41984, pitch=67, velocity=81),
#  Note(start=40960, end=43008, pitch=71, velocity=95),
#  Note(start=43008, end=44032, pitch=47, velocity=84),
#  Note(start=43008, end=44032, pitch=59, velocity=88),
#  Note(start=44032, end=45056, pitch=29, velocity=30),
#  Note(start=44032, end=45056, pitch=41, velocity=30),
#  Note(start=44032, end=45056, pitch=47, velocity=84),
#  Note(start=44032, end=45056, pitch=51, velocity=72),
#  Note(start=44032, end=45056, pitch=53, velocity=72),
#  Note(start=44032, end=45056, pitch=57, velocity=72),
#  Note(start=44032, end=46080, pitch=59, velocity=83),
#  Note(start=46080, end=47104, pitch=40, velocity=74),
#  Note(start=46080, end=47104, pitch=52, velocity=74),
#  Note(start=46080, end=47104, pitch=64, velocity=70),
#  Note(start=47104, end=48128, pitch=28, velocity=53),
#  Note(start=47104, end=48128, pitch=40, velocity=74),
#  Note(start=47104, end=48128, pitch=52, velocity=74),
#  Note(start=47104, end=48128, pitch=56, velocity=58),
#  Note(start=47104, end=48128, pitch=59, velocity=58),
#  Note(start=47104, end=48128, pitch=76, velocity=80),
#  Note(start=47104, end=49152, pitch=64, velocity=70),
#  Note(start=48128, end=49152, pitch=74, velocity=75),
#  Note(start=49152, end=50176, pitch=73, velocity=69),
#  Note(start=49152, end=52224, pitch=64, velocity=70),
#  Note(start=50176, end=51200, pitch=33, velocity=64),
#  Note(start=50176, end=51200, pitch=40, velocity=64),
#  Note(start=50176, end=51200, pitch=57, velocity=64),
#  Note(start=50176, end=51200, pitch=49, velocity=64),
#  Note(start=50176, end=51200, pitch=52, velocity=70),
#  Note(start=50176, end=51200, pitch=69, velocity=66),
#  Note(start=51200, end=52224, pitch=71, velocity=66),
#  Note(start=52224, end=53248, pitch=72, velocity=66),
#  Note(start=52224, end=55296, pitch=66, velocity=70),
#  Note(start=53248, end=54272, pitch=33, velocity=64),
#  Note(start=53248, end=54272, pitch=40, velocity=64),
#  Note(start=53248, end=54272, pitch=33, velocity=64),
#  Note(start=53248, end=54272, pitch=60, velocity=64),
#  Note(start=53248, end=54272, pitch=52, velocity=64),
#  Note(start=53248, end=54272, pitch=54, velocity=70),
#  Note(start=53248, end=54272, pitch=71, velocity=83),
#  Note(start=53248, end=54272, pitch=74, velocity=91),
#  Note(start=53248, end=54272, pitch=83, velocity=62),
#  Note(start=53248, end=54272, pitch=86, velocity=74),
#  Note(start=54272, end=55296, pitch=69, velocity=76),
#  Note(start=54272, end=55296, pitch=72, velocity=84),
#  Note(start=54272, end=55296, pitch=81, velocity=57),
#  Note(start=54272, end=55296, pitch=84, velocity=68),
#  Note(start=55296, end=56320, pitch=67, velocity=70),
#  Note(start=55296, end=56320, pitch=71, velocity=70),
#  Note(start=55296, end=56320, pitch=79, velocity=64),
#  Note(start=55296, end=56320, pitch=83, velocity=70),
#  Note(start=56320, end=57344, pitch=40, velocity=64),
#  Note(start=56320, end=57344, pitch=47, velocity=64),
#  Note(start=56320, end=57344, pitch=64, velocity=70),
#  Note(start=56320, end=57344, pitch=55, velocity=70),
#  Note(start=56320, end=57344, pitch=59, velocity=70),
#  Note(start=56320, end=57344, pitch=71, velocity=75),
#  Note(start=56320, end=57344, pitch=78, velocity=80),
#  Note(start=56320, end=57344, pitch=81, velocity=88),
#  Note(start=56320, end=57344, pitch=90, velocity=75),
#  Note(start=56320, end=57344, pitch=93, velocity=82),
#  Note(start=56320, end=58368, pitch=67, velocity=75),
#  Note(start=57344, end=58368, pitch=57, velocity=70),
#  Note(start=57344, end=58368, pitch=61, velocity=70),
#  Note(start=57344, end=58368, pitch=69, velocity=70),
#  Note(start=57344, end=58368, pitch=73, velocity=70),
#  Note(start=57344, end=58368, pitch=76, velocity=73),
#  Note(start=57344, end=58368, pitch=79, velocity=80),
#  Note(start=57344, end=58368, pitch=88, velocity=76),
#  Note(start=57344, end=58368, pitch=91, velocity=70),
#  Note(start=58368, end=59392, pitch=50, velocity=70),
#  Note(start=58368, end=59392, pitch=42, velocity=70),
#  Note(start=58368, end=59392, pitch=57, velocity=70),
#  Note(start=58368, end=59392, pitch=66, velocity=64),
#  Note(start=58368, end=59392, pitch=69, velocity=70),
#  Note(start=58368, end=59392, pitch=74, velocity=67),
#  Note(start=58368, end=59392, pitch=78, velocity=74),
#  Note(start=58368, end=59392, pitch=86, velocity=64),
#  Note(start=58368, end=59392, pitch=90, velocity=69),
#  Note(start=59392, end=60416, pitch=38, velocity=70),
#  Note(start=59392, end=60416, pitch=50, velocity=70),
#  Note(start=59392, end=60416, pitch=54, velocity=70),
#  Note(start=59392, end=60416, pitch=57, velocity=77),
#  Note(start=59392, end=60416, pitch=66, velocity=67),
#  Note(start=59392, end=60416, pitch=74, velocity=74),
#  Note(start=59392, end=60416, pitch=78, velocity=67),
#  Note(start=59392, end=60416, pitch=81, velocity=67),
#  Note(start=59392, end=60416, pitch=86, velocity=74),
#  Note(start=59392, end=61440, pitch=69, velocity=70),
#  Note(start=60416, end=61440, pitch=64, velocity=70),
#  Note(start=60416, end=61440, pitch=67, velocity=70),
#  Note(start=60416, end=61440, pitch=76, velocity=77),
#  Note(start=60416, end=61440, pitch=79, velocity=70),
#  Note(start=60416, end=61440, pitch=88, velocity=76),
#  Note(start=61440, end=62464, pitch=62, velocity=70),
#  Note(start=61440, end=62464, pitch=66, velocity=70),
#  Note(start=61440, end=62464, pitch=69, velocity=70),
#  Note(start=61440, end=62464, pitch=70, velocity=70),
#  Note(start=61440, end=62464, pitch=74, velocity=70),
#  Note(start=61440, end=62464, pitch=78, velocity=77),
#  Note(start=61440, end=62464, pitch=81, velocity=70),
#  Note(start=61440, end=62464, pitch=90, velocity=76),
#  Note(start=62464, end=63488, pitch=36, velocity=70),
#  Note(start=62464, end=63488, pitch=48, velocity=70),
#  Note(start=62464, end=63488, pitch=52, velocity=70),
#  Note(start=62464, end=63488, pitch=55, velocity=70),
#  Note(start=62464, end=63488, pitch=58, velocity=77),
#  Note(start=62464, end=63488, pitch=64, velocity=75),
#  Note(start=62464, end=63488, pitch=76, velocity=75),
#  Note(start=62464, end=63488, pitch=79, velocity=75),
#  Note(start=62464, end=63488, pitch=91, velocity=82),
#  Note(start=62464, end=65536, pitch=60, velocity=70),
#  Note(start=62464, end=65536, pitch=70, velocity=70),
#  Note(start=62464, end=65536, pitch=82, velocity=70),
#  Note(start=63488, end=64512, pitch=66, velocity=70),
#  Note(start=63488, end=64512, pitch=78, velocity=70),
#  Note(start=63488, end=64512, pitch=90, velocity=76),
#  Note(start=64512, end=65536, pitch=67, velocity=70),
#  Note(start=64512, end=65536, pitch=71, velocity=70),
#  Note(start=64512, end=65536, pitch=76, velocity=70),
#  Note(start=64512, end=65536, pitch=79, velocity=70),
#  Note(start=64512, end=65536, pitch=88, velocity=70),
#  Note(start=65536, end=66560, pitch=35, velocity=70),
#  Note(start=65536, end=66560, pitch=47, velocity=70),
#  Note(start=65536, end=66560, pitch=52, velocity=70),
#  Note(start=65536, end=66560, pitch=55, velocity=70),
#  Note(start=65536, end=66560, pitch=59, velocity=77),
#  Note(start=65536, end=66560, pitch=64, velocity=70),
#  Note(start=65536, end=66560, pitch=67, velocity=75),
#  Note(start=65536, end=66560, pitch=76, velocity=69),
#  Note(start=65536, end=66560, pitch=79, velocity=77),
#  Note(start=65536, end=67584, pitch=71, velocity=70),
#  Note(start=66560, end=67584, pitch=57, velocity=70),
#  Note(start=66560, end=67584, pitch=66, velocity=70),
#  Note(start=66560, end=67584, pitch=69, velocity=70),
#  Note(start=66560, end=67584, pitch=78, velocity=68),
#  Note(start=66560, end=67584, pitch=81, velocity=74),
#  Note(start=67584, end=68608, pitch=55, velocity=70),
#  Note(start=67584, end=68608, pitch=59, velocity=70),
#  Note(start=67584, end=68608, pitch=67, velocity=71),
#  Note(start=67584, end=68608, pitch=71, velocity=71),
#  Note(start=67584, end=68608, pitch=79, velocity=71),
#  Note(start=67584, end=68608, pitch=83, velocity=78),
#  Note(start=67584, end=69632, pitch=64, velocity=70),
#  Note(start=67584, end=69632, pitch=76, velocity=71),
#  Note(start=68608, end=69632, pitch=35, velocity=70),
#  Note(start=68608, end=69632, pitch=59, velocity=70),
#  Note(start=68608, end=69632, pitch=66, velocity=70),
#  Note(start=68608, end=69632, pitch=69, velocity=74),
#  Note(start=68608, end=69632, pitch=73, velocity=74),
#  Note(start=68608, end=69632, pitch=81, velocity=74),
#  Note(start=68608, end=69632, pitch=85, velocity=81),
#  Note(start=68608, end=70656, pitch=47, velocity=77),
#  Note(start=68608, end=70656, pitch=54, velocity=73),
#  Note(start=69632, end=70656, pitch=59, velocity=70),
#  Note(start=69632, end=70656, pitch=66, velocity=75),
#  Note(start=69632, end=70656, pitch=71, velocity=76),
#  Note(start=69632, end=70656, pitch=75, velocity=76),
#  Note(start=69632, end=70656, pitch=78, velocity=75),
#  Note(start=69632, end=70656, pitch=87, velocity=83),
#  Note(start=70656, end=71680, pitch=51, velocity=79),
#  Note(start=70656, end=71680, pitch=59, velocity=79),
#  Note(start=70656, end=71680, pitch=63, velocity=74),
#  Note(start=70656, end=71680, pitch=64, velocity=70),
#  Note(start=70656, end=71680, pitch=71, velocity=78),
#  Note(start=70656, end=71680, pitch=72, velocity=79),
#  Note(start=70656, end=71680, pitch=75, velocity=79),
#  Note(start=70656, end=71680, pitch=81, velocity=79),
#  Note(start=70656, end=71680, pitch=84, velocity=78),
#  Note(start=70656, end=71680, pitch=93, velocity=86),
#  Note(start=71680, end=72704, pitch=40, velocity=82),
#  Note(start=71680, end=72704, pitch=52, velocity=82),
#  Note(start=71680, end=72704, pitch=61, velocity=80),
#  Note(start=71680, end=72704, pitch=71, velocity=82),
#  Note(start=71680, end=72704, pitch=73, velocity=82),
#  Note(start=71680, end=72704, pitch=76, velocity=82),
#  Note(start=71680, end=72704, pitch=79, velocity=82),
#  Note(start=71680, end=72704, pitch=83, velocity=82),
#  Note(start=71680, end=72704, pitch=91, velocity=89),
#  Note(start=71680, end=73728, pitch=64, velocity=80),
#  Note(start=72704, end=73728, pitch=31, velocity=75),
#  Note(start=72704, end=73728, pitch=43, velocity=88),
#  Note(start=72704, end=73728, pitch=67, velocity=88),
#  Note(start=72704, end=73728, pitch=63, velocity=102),
#  Note(start=72704, end=73728, pitch=66, velocity=102),
#  Note(start=72704, end=73728, pitch=69, velocity=102),
#  Note(start=72704, end=73728, pitch=75, velocity=102),
#  Note(start=72704, end=73728, pitch=78, velocity=102),
#  Note(start=72704, end=73728, pitch=81, velocity=102),
#  Note(start=72704, end=73728, pitch=90, velocity=111),
#  Note(start=73728, end=74752, pitch=36, velocity=91),
#  Note(start=73728, end=74752, pitch=48, velocity=88),
#  Note(start=73728, end=74752, pitch=40, velocity=88),
#  Note(start=73728, end=74752, pitch=67, velocity=91),
#  Note(start=73728, end=74752, pitch=60, velocity=88),
#  Note(start=73728, end=74752, pitch=67, velocity=91),
#  Note(start=73728, end=74752, pitch=72, velocity=88),
#  Note(start=73728, end=74752, pitch=76, velocity=103),
#  Note(start=73728, end=74752, pitch=79, velocity=91),
#  Note(start=73728, end=74752, pitch=88, velocity=107),
#  Note(start=73728, end=75776, pitch=64, velocity=96),
#  Note(start=74752, end=75776, pitch=43, velocity=88),
#  Note(start=74752, end=75776, pitch=42, velocity=88),
#  Note(start=74752, end=75776, pitch=67, velocity=88),
#  Note(start=74752, end=75776, pitch=59, velocity=88),
#  Note(start=74752, end=75776, pitch=63, velocity=96),
#  Note(start=74752, end=75776, pitch=66, velocity=88),
#  Note(start=74752, end=75776, pitch=71, velocity=88),
#  Note(start=74752, end=75776, pitch=75, velocity=88),
#  Note(start=74752, end=75776, pitch=83, velocity=88),
#  Note(start=74752, end=75776, pitch=87, velocity=96),
#  Note(start=75776, end=76800, pitch=48, velocity=88),
#  Note(start=75776, end=76800, pitch=67, velocity=88),
#  Note(start=75776, end=76800, pitch=60, velocity=96),
#  Note(start=75776, end=76800, pitch=64, velocity=96),
#  Note(start=75776, end=76800, pitch=67, velocity=88),
#  Note(start=75776, end=76800, pitch=72, velocity=88),
#  Note(start=75776, end=76800, pitch=76, velocity=88),
#  Note(start=75776, end=76800, pitch=84, velocity=88),
#  Note(start=75776, end=76800, pitch=88, velocity=96),
#  Note(start=76800, end=77824, pitch=35, velocity=88),
#  Note(start=76800, end=77824, pitch=47, velocity=91),
#  Note(start=76800, end=77824, pitch=59, velocity=91),
#  Note(start=76800, end=77824, pitch=63, velocity=91),
#  Note(start=76800, end=77824, pitch=71, velocity=91),
#  Note(start=76800, end=77824, pitch=75, velocity=91),
#  Note(start=76800, end=77824, pitch=87, velocity=91),
#  Note(start=76800, end=79872, pitch=66, velocity=96),
#  Note(start=76800, end=79872, pitch=78, velocity=103),
#  Note(start=76800, end=79872, pitch=90, velocity=107),
#  Note(start=77824, end=78848, pitch=42, velocity=88),
#  Note(start=77824, end=78848, pitch=42, velocity=88),
#  Note(start=77824, end=78848, pitch=58, velocity=88),
#  Note(start=77824, end=78848, pitch=61, velocity=88),
#  Note(start=77824, end=78848, pitch=70, velocity=88),
#  Note(start=77824, end=78848, pitch=73, velocity=88),
#  Note(start=77824, end=78848, pitch=85, velocity=88),
#  Note(start=78848, end=79872, pitch=35, velocity=88),
#  Note(start=78848, end=79872, pitch=47, velocity=88),
#  Note(start=78848, end=79872, pitch=59, velocity=88),
#  Note(start=78848, end=79872, pitch=63, velocity=88),
#  Note(start=78848, end=79872, pitch=71, velocity=88),
#  Note(start=78848, end=79872, pitch=75, velocity=88),
#  Note(start=78848, end=79872, pitch=87, velocity=88),
#  Note(start=79872, end=80896, pitch=40, velocity=91),
#  Note(start=79872, end=80896, pitch=40, velocity=88),
#  Note(start=79872, end=80896, pitch=59, velocity=91),
#  Note(start=79872, end=80896, pitch=64, velocity=88),
#  Note(start=79872, end=80896, pitch=71, velocity=91),
#  Note(start=79872, end=80896, pitch=76, velocity=91),
#  Note(start=79872, end=80896, pitch=79, velocity=103),
#  Note(start=79872, end=80896, pitch=88, velocity=91),
#  Note(start=79872, end=80896, pitch=91, velocity=107),
#  Note(start=79872, end=81920, pitch=67, velocity=96),
#  Note(start=80896, end=81920, pitch=47, velocity=88),
#  Note(start=80896, end=81920, pitch=57, velocity=88),
#  Note(start=80896, end=81920, pitch=59, velocity=88),
#  Note(start=80896, end=81920, pitch=63, velocity=88),
#  Note(start=80896, end=81920, pitch=66, velocity=96),
#  Note(start=80896, end=81920, pitch=69, velocity=88),
#  Note(start=80896, end=81920, pitch=75, velocity=88),
#  Note(start=80896, end=81920, pitch=78, velocity=88),
#  Note(start=80896, end=81920, pitch=87, velocity=88),
#  Note(start=80896, end=81920, pitch=90, velocity=96),
#  Note(start=81920, end=82944, pitch=40, velocity=88),
#  Note(start=81920, end=82944, pitch=59, velocity=88),
#  Note(start=81920, end=82944, pitch=64, velocity=88),
#  Note(start=81920, end=82944, pitch=67, velocity=96),
#  Note(start=81920, end=82944, pitch=71, velocity=88),
#  Note(start=81920, end=82944, pitch=76, velocity=88),
#  Note(start=81920, end=82944, pitch=79, velocity=88),
#  Note(start=81920, end=82944, pitch=88, velocity=88),
#  Note(start=81920, end=82944, pitch=91, velocity=96),
#  Note(start=82944, end=83968, pitch=50, velocity=91),
#  Note(start=82944, end=83968, pitch=62, velocity=91),
#  Note(start=82944, end=83968, pitch=66, velocity=91),
#  Note(start=82944, end=83968, pitch=74, velocity=91),
#  Note(start=82944, end=83968, pitch=78, velocity=91),
#  Note(start=82944, end=83968, pitch=90, velocity=91),
#  Note(start=82944, end=86016, pitch=69, velocity=102),
#  Note(start=82944, end=86016, pitch=81, velocity=105),
#  Note(start=82944, end=86016, pitch=93, velocity=107),
#  Note(start=83968, end=84992, pitch=45, velocity=88),
#  Note(start=83968, end=84992, pitch=57, velocity=88),
#  Note(start=83968, end=84992, pitch=61, velocity=88),
#  Note(start=83968, end=84992, pitch=64, velocity=88),
#  Note(start=83968, end=84992, pitch=73, velocity=88),
#  Note(start=83968, end=84992, pitch=76, velocity=88),
#  Note(start=83968, end=84992, pitch=88, velocity=88),
#  Note(start=84992, end=86016, pitch=38, velocity=88),
#  Note(start=84992, end=86016, pitch=50, velocity=88),
#  Note(start=84992, end=86016, pitch=62, velocity=88),
#  Note(start=84992, end=86016, pitch=66, velocity=88),
#  Note(start=84992, end=86016, pitch=74, velocity=88),
#  Note(start=84992, end=86016, pitch=78, velocity=88),
#  Note(start=84992, end=86016, pitch=90, velocity=88),
#  Note(start=86016, end=87040, pitch=30, velocity=104),
#  Note(start=86016, end=87040, pitch=42, velocity=90),
#  Note(start=86016, end=87040, pitch=42, velocity=88),
#  Note(start=86016, end=87040, pitch=58, velocity=106),
#  Note(start=86016, end=87040, pitch=61, velocity=108),
#  Note(start=86016, end=87040, pitch=66, velocity=102),
#  Note(start=86016, end=87040, pitch=73, velocity=105),
#  Note(start=86016, end=87040, pitch=76, velocity=88),
#  Note(start=86016, end=87040, pitch=78, velocity=106),
#  Note(start=86016, end=87040, pitch=82, velocity=107),
#  Note(start=86016, end=87040, pitch=85, velocity=116),
#  Note(start=86016, end=88064, pitch=70, velocity=111),
#  Note(start=86016, end=89088, pitch=64, velocity=88),
#  Note(start=87040, end=88064, pitch=35, velocity=101),
#  Note(start=87040, end=88064, pitch=47, velocity=88),
#  Note(start=87040, end=88064, pitch=68, velocity=103),
#  Note(start=87040, end=88064, pitch=59, velocity=105),
#  Note(start=87040, end=88064, pitch=62, velocity=105),
#  Note(start=87040, end=88064, pitch=68, velocity=107),
#  Note(start=87040, end=88064, pitch=71, velocity=102),
#  Note(start=87040, end=88064, pitch=74, velocity=103),
#  Note(start=87040, end=88064, pitch=80, velocity=104),
#  Note(start=87040, end=88064, pitch=83, velocity=113),
#  Note(start=88064, end=89088, pitch=42, velocity=101),
#  Note(start=88064, end=89088, pitch=42, velocity=88),
#  Note(start=88064, end=89088, pitch=58, velocity=103),
#  Note(start=88064, end=89088, pitch=61, velocity=105),
#  Note(start=88064, end=89088, pitch=66, velocity=96),
#  Note(start=88064, end=89088, pitch=70, velocity=104),
#  Note(start=88064, end=89088, pitch=73, velocity=102),
#  Note(start=88064, end=89088, pitch=78, velocity=103),
#  Note(start=88064, end=89088, pitch=82, velocity=104),
#  Note(start=88064, end=89088, pitch=85, velocity=113),
#  Note(start=89088, end=90112, pitch=31, velocity=104),
#  Note(start=89088, end=90112, pitch=43, velocity=88),
#  Note(start=89088, end=90112, pitch=67, velocity=90),
#  Note(start=89088, end=90112, pitch=59, velocity=106),
#  Note(start=89088, end=90112, pitch=64, velocity=108),
#  Note(start=89088, end=90112, pitch=67, velocity=102),
#  Note(start=89088, end=90112, pitch=76, velocity=106),
#  Note(start=89088, end=90112, pitch=83, velocity=107),
#  Note(start=89088, end=90112, pitch=88, velocity=116),
#  Note(start=89088, end=91136, pitch=71, velocity=111),
#  Note(start=90112, end=91136, pitch=40, velocity=101),
#  Note(start=90112, end=91136, pitch=40, velocity=88),
#  Note(start=90112, end=91136, pitch=58, velocity=103),
#  Note(start=90112, end=91136, pitch=64, velocity=98),
#  Note(start=90112, end=91136, pitch=66, velocity=105),
#  Note(start=90112, end=91136, pitch=70, velocity=107),
#  Note(start=90112, end=91136, pitch=78, velocity=103),
#  Note(start=90112, end=91136, pitch=82, velocity=104),
#  Note(start=90112, end=91136, pitch=90, velocity=113),
#  Note(start=91136, end=92160, pitch=43, velocity=101),
#  Note(start=91136, end=92160, pitch=67, velocity=88),
#  Note(start=91136, end=92160, pitch=59, velocity=103),
#  Note(start=91136, end=92160, pitch=64, velocity=95),
#  Note(start=91136, end=92160, pitch=67, velocity=105),
#  Note(start=91136, end=92160, pitch=71, velocity=104),
#  Note(start=91136, end=92160, pitch=76, velocity=102),
#  Note(start=91136, end=92160, pitch=79, velocity=103),
#  Note(start=91136, end=92160, pitch=83, velocity=104),
#  Note(start=91136, end=92160, pitch=91, velocity=113),
#  Note(start=92160, end=93184, pitch=35, velocity=104),
#  Note(start=92160, end=93184, pitch=47, velocity=88),
#  Note(start=92160, end=93184, pitch=57, velocity=88),
#  Note(start=92160, end=93184, pitch=63, velocity=106),
#  Note(start=92160, end=93184, pitch=66, velocity=108),
#  Note(start=92160, end=93184, pitch=71, velocity=103),
#  Note(start=92160, end=93184, pitch=75, velocity=111),
#  Note(start=92160, end=93184, pitch=78, velocity=106),
#  Note(start=92160, end=93184, pitch=81, velocity=107),
#  Note(start=92160, end=93184, pitch=87, velocity=116),
#  Note(start=92160, end=95232, pitch=59, velocity=96),
#  Note(start=92160, end=95232, pitch=69, velocity=102),
#  Note(start=93184, end=94208, pitch=42, velocity=101),
#  Note(start=93184, end=94208, pitch=42, velocity=88),
#  Note(start=93184, end=94208, pitch=61, velocity=103),
#  Note(start=93184, end=94208, pitch=64, velocity=105),
#  Note(start=93184, end=94208, pitch=73, velocity=111),
#  Note(start=93184, end=94208, pitch=76, velocity=103),
#  Note(start=93184, end=94208, pitch=81, velocity=104),
#  Note(start=93184, end=94208, pitch=85, velocity=113),
#  Note(start=94208, end=95232, pitch=47, velocity=101),
#  Note(start=94208, end=95232, pitch=63, velocity=103),
#  Note(start=94208, end=95232, pitch=66, velocity=105),
#  Note(start=94208, end=95232, pitch=75, velocity=111),
#  Note(start=94208, end=95232, pitch=78, velocity=103),
#  Note(start=94208, end=95232, pitch=81, velocity=104),
#  Note(start=94208, end=95232, pitch=87, velocity=113),
#  Note(start=95232, end=96256, pitch=40, velocity=101),
#  Note(start=95232, end=96256, pitch=40, velocity=88),
#  Note(start=95232, end=96256, pitch=57, velocity=88),
#  Note(start=95232, end=96256, pitch=69, velocity=88),
#  Note(start=95232, end=96256, pitch=72, velocity=93),
#  Note(start=95232, end=96256, pitch=98, velocity=101),
#  Note(start=95232, end=97280, pitch=60, velocity=101),
#  Note(start=95232, end=99328, pitch=64, velocity=101),
#  Note(start=95232, end=99328, pitch=76, velocity=103),
#  Note(start=95232, end=99328, pitch=88, velocity=110),
#  Note(start=96256, end=97280, pitch=45, velocity=99),
#  Note(start=96256, end=97280, pitch=57, velocity=86),
#  Note(start=96256, end=97280, pitch=59, velocity=99),
#  Note(start=96256, end=97280, pitch=62, velocity=99),
#  Note(start=96256, end=97280, pitch=71, velocity=88),
#  Note(start=96256, end=97280, pitch=74, velocity=99),
#  Note(start=96256, end=97280, pitch=83, velocity=99),
#  Note(start=96256, end=97280, pitch=86, velocity=99),
#  Note(start=97280, end=98304, pitch=48, velocity=96),
#  Note(start=97280, end=98304, pitch=57, velocity=96),
#  Note(start=97280, end=98304, pitch=60, velocity=96),
#  Note(start=97280, end=98304, pitch=69, velocity=88),
#  Note(start=97280, end=98304, pitch=72, velocity=96),
#  Note(start=97280, end=98304, pitch=81, velocity=96),
#  Note(start=97280, end=98304, pitch=84, velocity=96),
#  Note(start=98304, end=98816, pitch=67, velocity=95),
#  Note(start=98304, end=98816, pitch=59, velocity=110),
#  Note(start=98304, end=99328, pitch=40, velocity=88),
#  Note(start=98304, end=99328, pitch=40, velocity=95),
#  Note(start=98304, end=99328, pitch=67, velocity=88),
#  Note(start=98304, end=99328, pitch=71, velocity=95),
#  Note(start=98304, end=99328, pitch=79, velocity=95),
#  Note(start=98304, end=99328, pitch=83, velocity=95),
#  Note(start=98816, end=99328, pitch=67, velocity=95),
#  Note(start=98816, end=99840, pitch=59, velocity=95),
#  Note(start=99328, end=99840, pitch=64, velocity=110),
#  Note(start=99328, end=101376, pitch=28, velocity=88),
#  Note(start=99328, end=101376, pitch=40, velocity=88),
#  Note(start=99840, end=101376, pitch=67, velocity=69),
#  Note(start=99840, end=101376, pitch=59, velocity=69),
#  Note(start=99840, end=101376, pitch=64, velocity=69),
#  Note(start=100864, end=101376, pitch=71, velocity=110)]

# %% [raw]
# def mergeIntervals(arr):
#         # Sorting based on the increasing order
#         # of the start intervals
#         arr.sort(key = lambda x: x[0])
#         # array to hold the merged intervals
#         m = []
#         s = -10000
#         max = -100000
#         for i in range(len(arr)):
#             a = arr[i]
#             if a[0] > max:
#                 if i != 0:
#                     m.append([s,max])
#                 max = a[1]
#                 s = a[0]
#             else:
#                 if a[1] >= max:
#                     max = a[1]
#         #'max' value gives the last point of
#         # that particular interval
#         # 's' gives the starting point of that interval
#         # 'm' array contains the list of all merged intervals
#         if max != -100000 and [s, max] not in m:
#             m.append([s, max])
#         return m
#
# def gettop(note,intervals):
#     note_interval = [note.start,note.end]#onset,offset
#     overlap_time = 0
#     total_time = note.end - note.start #offset-onset
#     if total_time == 0:
#         return 1 #(we do not need this note)
#     for interval in intervals:
#         maxstart = max(note_interval[0],interval[0])
#         minend = min(note_interval[1],interval[1])
#         if maxstart < minend:
#             overlap_time += minend-maxstart
#     return overlap_time/total_time
#
# def skyline(notes): #revised skyline algorithm by Chai, 2000
#     #Performed on a single channel
#     accepted_notes = []
#     notes = sorted(notes, key=lambda x: x.pitch, reverse=True) #sort by pitch
#     intervals = []
#     for note in notes:
#         if gettop(note,intervals) <=0.1:
#             accepted_notes.append(note)
#             intervals.append([note.start,note.end]) #onset,offset
#             intervals = mergeIntervals(intervals)
#     return sorted(accepted_notes,key=lambda x: x.start) #sort by onset & bar(new)
#
# def skyline_reverse(notes): #revised skyline algorithm by Chai, 2000
#     #Performed on a single channel
#     accepted_notes = []
#     notes = sorted(notes, key=lambda x: x.pitch) #sort by pitch
#     intervals = []
#     for note in notes:
#         if gettop(note,intervals) <=0.1:
#             accepted_notes.append(note)
#             intervals.append([note.start,note.end]) #onset,offset
#             intervals = mergeIntervals(intervals)
#     return sorted(accepted_notes,key=lambda x: x.start) #sort by onset & bar(new)

# %%
notes
