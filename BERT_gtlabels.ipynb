# %%
from miditoolkit.midi import parser as mid_parser  
from miditoolkit.midi import containers as ct
from numpy import array, linspace
from sklearn.neighbors import KernelDensity
from matplotlib.pyplot import plot
from scipy.signal import argrelextrema
from scipy.ndimage import gaussian_filter1d
import numpy as np
from miditoolkit.pianoroll import parser as pr_parser
from miditoolkit.pianoroll import utils
import matplotlib.pyplot as plt

# %%
# helper functions
def read_midi(path):
    mido_obj = mid_parser.MidiFile(path)
    tick_per_beat = mido_obj.ticks_per_beat

    notes = [] 
    for instrument in mido_obj.instruments:
        if instrument.is_drum:
            continue
        for note in instrument.notes:
            notes.append(note)

    # sort by start time
    notes.sort(key=lambda note:note.start)
    return notes,tick_per_beat
    
def write_midi(notes,path='out.mid',tick_per_beat=480):
    out = mid_parser.MidiFile()
    out.ticks_per_beat = tick_per_beat
    out.instruments = [ct.Instrument(program=0,is_drum=False,name='kept notes')]
    for note in notes:
        assert(note.velocity)
        out.instruments[0].notes.append(ct.Note(start=note.start,end=note.end,pitch=note.pitch,velocity=note.velocity))
    out.dump(path)

# %%
def mergeIntervals(arr):
        # Sorting based on the increasing order 
        # of the start intervals
        arr.sort(key = lambda x: x[0]) 
        # array to hold the merged intervals
        m = []
        s = -10000
        max = -100000
        for i in range(len(arr)):
            a = arr[i]
            if a[0] > max:
                if i != 0:
                    m.append([s,max])
                max = a[1]
                s = a[0]
            else:
                if a[1] >= max:
                    max = a[1]        
        #'max' value gives the last point of 
        # that particular interval
        # 's' gives the starting point of that interval
        # 'm' array contains the list of all merged intervals
        if max != -100000 and [s, max] not in m:
            m.append([s, max])
        return m

# %%
def interval_histogram(notep):
    hist_p = dict()
    for note in notep:
        if note.pitch in hist_p:
            hist_p[note.pitch].append([note.start,note.end])
            hist_p[note.pitch] = mergeIntervals(hist_p[note.pitch])
        else:
            hist_p[note.pitch] = [[note.start,note.end]]    
    return hist_p

def find_intersect(note,intervals):
    def is_overlapping(x1,x2,y1,y2):
        return max(x1,y1) < min(x2,y2)
    for inte in intervals:
        if is_overlapping(note.start,note.end,inte[0],inte[1]):
            return True
    return False

# %%
import os
paired_data=[]
data_path='./'
paired=['LOP']
extracted_o_count=0
root_path = os.walk(data_path+paired[0])
for root, directories, files in root_path:
    for d in directories:
        print(d)
        noteo,tpbo = read_midi(root+'/'+d+"/orchestra.mid")
        notep,tpbp = read_midi(root+'/'+d+"/piano.mid")
        try:
            assert tpbo==tpbp
        except:
            print("GG", d)
            write_midi(noteo,root+'/'+d+"/dontuse.mid",tpbo)
            continue
        histp = interval_histogram(notep)
        kept_notes = []
        # print("Total notes:", len(noteo))
        for note in noteo:
            if note.pitch not in histp:
                continue
            if find_intersect(note,histp[note.pitch]):
                kept_notes.append(note)
        print("Kept notes:" ,len(kept_notes)/len(noteo))
        if len(kept_notes)/len(noteo) < 0.5:
            # write_midi(noteo,root+'/'+d+"/dontuse.mid",tpbo)
            print(d, "DONTUSE")
        kept_notes = sorted(kept_notes,key=lambda x: x.start)
        # write_midi(kept_notes,root+'/'+d+"/labels.mid",tpbo)
# Out:
# bouliane-0
# Kept notes: 0.9914965986394558
# bouliane-1
# Kept notes: 0.7278828553996339
# bouliane-10
# Kept notes: 0.6909090909090909
# bouliane-11
# Kept notes: 0.974025974025974
# bouliane-12
# Kept notes: 0.9799599198396793
# bouliane-13
# Kept notes: 0.8341968911917098
# bouliane-14
# Kept notes: 0.9975609756097561
# bouliane-15
# Kept notes: 0.7927461139896373
# bouliane-16
# Kept notes: 0.845861084681256
# bouliane-17
# Kept notes: 0.8616684266103485
# bouliane-18
# Kept notes: 0.8928571428571429
# bouliane-19
# Kept notes: 0.675032175032175
# bouliane-2
# Kept notes: 0.8666666666666667
# bouliane-20
# Kept notes: 0.9939789262418465
# bouliane-21
# Kept notes: 0.8392857142857143
# bouliane-22
# Kept notes: 1.0
# bouliane-23
# Kept notes: 0.9846153846153847
# bouliane-24
# Kept notes: 0.9346016646848989
# bouliane-25
# Kept notes: 0.7194656488549618
# bouliane-26
# Kept notes: 0.8148148148148148
# bouliane-27
# Kept notes: 0.9938271604938271
# bouliane-28
# Kept notes: 0.9911616161616161
# bouliane-29
# Kept notes: 0.9333333333333333
# bouliane-3
# Kept notes: 0.9016152716593245
# bouliane-30
# Kept notes: 1.0
# bouliane-31
# Kept notes: 0.9875643224699828
# bouliane-32
# Kept notes: 0.7605633802816901
# bouliane-33
# Kept notes: 0.7038643533123028
# bouliane-34
# Kept notes: 0.8508604206500956
# bouliane-35
# Kept notes: 0.7145359019264448
# bouliane-36
# Kept notes: 0.9927884615384616
# bouliane-37
# Kept notes: 0.9939759036144579
# bouliane-38
# Kept notes: 1.0
# bouliane-39
# Kept notes: 0.8787878787878788
# bouliane-4
# Kept notes: 0.8346213292117465
# bouliane-5
# Kept notes: 0.9543859649122807
# bouliane-6
# Kept notes: 0.9954954954954955
# bouliane-7
# Kept notes: 0.8243831640058055
# bouliane-8
# Kept notes: 0.6505660377358491
# bouliane-9
# Kept notes: 1.0
# hand_picked_Spotify-0
# Kept notes: 0.6994949494949495
# hand_picked_Spotify-10
# Kept notes: 0.9083333333333333
# hand_picked_Spotify-11
# Kept notes: 0.6297141957326194
# hand_picked_Spotify-12
# Kept notes: 0.8791827065442701
# hand_picked_Spotify-13
# Kept notes: 0.6278254091971941
# hand_picked_Spotify-15
# Kept notes: 0.7853982300884956
# hand_picked_Spotify-16
# Kept notes: 0.870594990310773
# hand_picked_Spotify-17
# Kept notes: 0.9790575916230366
# hand_picked_Spotify-18
# Kept notes: 0.3508771929824561
# hand_picked_Spotify-18 DONTUSE
# hand_picked_Spotify-19
# Kept notes: 0.512414083321644
# hand_picked_Spotify-2
# Kept notes: 0.31952662721893493
# hand_picked_Spotify-2 DONTUSE
# hand_picked_Spotify-20
# Kept notes: 0.6354885579367963
# hand_picked_Spotify-21
# Kept notes: 0.9164631167562286
# hand_picked_Spotify-22
# Kept notes: 0.5506810106592973
# hand_picked_Spotify-23
# Kept notes: 0.7397991431982583
# hand_picked_Spotify-24
# Kept notes: 0.6361793196665916
# hand_picked_Spotify-31
# Kept notes: 0.6068147013782542
# hand_picked_Spotify-32
# Kept notes: 0.7176086727712873
# hand_picked_Spotify-33
# Kept notes: 0.5470363444182453
# hand_picked_Spotify-34
# Kept notes: 0.7231719876416066
# hand_picked_Spotify-35
# Kept notes: 0.751467944877172
# hand_picked_Spotify-36
# Kept notes: 0.7476901701979854
# hand_picked_Spotify-37
# Kept notes: 0.6461883408071749
# hand_picked_Spotify-39
# Kept notes: 0.5591093117408907
# hand_picked_Spotify-4
# Kept notes: 0.5918013856812933
# hand_picked_Spotify-40
# Kept notes: 0.7551949900370054
# hand_picked_Spotify-41
# Kept notes: 0.7380510440835267
# hand_picked_Spotify-42
# Kept notes: 0.7429438543247344
# hand_picked_Spotify-43
# Kept notes: 0.7484504132231405
# hand_picked_Spotify-44
# Kept notes: 0.6612787870118724
# hand_picked_Spotify-45
# Kept notes: 0.7559302657902258
# hand_picked_Spotify-46
# Kept notes: 0.6345939933259177
# hand_picked_Spotify-47
# Kept notes: 0.6567196689174472
# hand_picked_Spotify-48
# Kept notes: 0.8448489863467108
# hand_picked_Spotify-49
# Kept notes: 0.8732989206945097
# hand_picked_Spotify-5
# Kept notes: 0.6340447683498178
# hand_picked_Spotify-50
# Kept notes: 0.6527603949381171
# hand_picked_Spotify-51
# Kept notes: 0.6287205257054503
# hand_picked_Spotify-52
# Kept notes: 0.7114908370480436
# hand_picked_Spotify-53
# Kept notes: 0.6239804241435563
# hand_picked_Spotify-54
# Kept notes: 0.6456778102347722
# hand_picked_Spotify-55
# Kept notes: 0.5714793899239629
# hand_picked_Spotify-56
# Kept notes: 0.6327279077890324
# hand_picked_Spotify-57
# Kept notes: 0.8967082860385925
# hand_picked_Spotify-58
# Kept notes: 0.6185210780926054
# hand_picked_Spotify-59
# GG hand_picked_Spotify-59
# hand_picked_Spotify-6
# Kept notes: 0.5130382049727107
# hand_picked_Spotify-60
# Kept notes: 0.5275720164609053
# hand_picked_Spotify-61
# Kept notes: 0.6576836516821513
# hand_picked_Spotify-62
# GG hand_picked_Spotify-62
# hand_picked_Spotify-63
# GG hand_picked_Spotify-63
# hand_picked_Spotify-64
# GG hand_picked_Spotify-64
# hand_picked_Spotify-7
# Kept notes: 0.6297310355934933
# hand_picked_Spotify-8
# Kept notes: 0.8704472843450479
# hand_picked_Spotify-9
# Kept notes: 0.5897129186602871
# liszt_classical_archives-0
# GG liszt_classical_archives-0
# liszt_classical_archives-1
# Kept notes: 0.6696049988841777
# liszt_classical_archives-10
# Kept notes: 0.5422622285968643
# liszt_classical_archives-11
# Kept notes: 0.755933241463788
# liszt_classical_archives-12
# Kept notes: 0.708814928282969
# liszt_classical_archives-13
# Kept notes: 0.5245531329797682
# liszt_classical_archives-14
# Kept notes: 0.6012086513994911
# liszt_classical_archives-15
# Kept notes: 0.661266013564431
# liszt_classical_archives-16
# Kept notes: 0.7540639748295752
# liszt_classical_archives-17
# Kept notes: 0.6853293413173652
# liszt_classical_archives-18
# Kept notes: 0.5953650793650793
# liszt_classical_archives-19
# Kept notes: 0.6469157118191806
# liszt_classical_archives-2
# Kept notes: 0.7118717976670664
# liszt_classical_archives-20
# Kept notes: 0.6502489331436699
# liszt_classical_archives-21
# Kept notes: 0.7117400419287212
# liszt_classical_archives-22
# Kept notes: 0.7998259355961705
# liszt_classical_archives-23
# Kept notes: 0.6099421064350924
# liszt_classical_archives-24
# Kept notes: 0.6062727098871677
# liszt_classical_archives-25
# Kept notes: 0.6038792557904062
# liszt_classical_archives-26
# Kept notes: 0.737804109416362
# liszt_classical_archives-27
# Kept notes: 0.6630387580067311
# liszt_classical_archives-28
# Kept notes: 0.6927588540491766
# liszt_classical_archives-29
# Kept notes: 0.667195702600415
# liszt_classical_archives-3
# Kept notes: 0.6776870566189265
# liszt_classical_archives-30
# Kept notes: 0.7357589121646454
# liszt_classical_archives-31
# Kept notes: 0.7889315289840436
# liszt_classical_archives-32
# Kept notes: 0.66711851278079
# liszt_classical_archives-33
# Kept notes: 0.6543002970975851
# liszt_classical_archives-4
# Kept notes: 0.571697695035461
# liszt_classical_archives-5
# Kept notes: 0.7765448958688972
# liszt_classical_archives-6
# Kept notes: 0.7535979572887651
# liszt_classical_archives-7
# Kept notes: 0.6546664649826047
# liszt_classical_archives-8
# Kept notes: 0.7067558376785309
# liszt_classical_archives-9
# Kept notes: 0.7688876498466686

# %%
noteo, tpbo = read_midi("./LOP/hand_picked_Spotify-33/orchestra.mid")
notep, tpbp = read_midi("./LOP/hand_picked_Spotify-33/piano.mid")
assert tpbo==tpbp
histp = interval_histogram(notep)
kept_notes = []
# print("Total notes:", len(noteo))
for note in noteo:
    if note.pitch not in histp:
        continue
    # print(note.start,note.end,note.pitch)
    if find_intersect(note,histp[note.pitch]):
        kept_notes.append(note)
print("Kept notes:" ,len(kept_notes)/len(noteo))
kept_notes = sorted(kept_notes,key=lambda x: x.start)
write_midi(kept_notes,"labels.mid",tpbo)
# Out:
# Kept notes: 0.5470363444182453
